# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
'''
0 t
1 d
2 r
3 a
4 b
5 ab
6 dab
7 a + ab
'''

# %%
A = np.loadtxt('a.dat')

# %%
plot(A[:,0],A[:,3])
plot(A[:,0],A[:,4])

# %%
plot(A[:,0],A[:,5])

# %%
plot(A[:,0],A[:,7])
