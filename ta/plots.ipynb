# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
'''
0 t
1 d
2 r
3 a
4 b
5 ab
6 dab
7 a + ab
'''

# %%
one = np.loadtxt('one_cell.dat')

# %%
plot(A[:,0],one[:,3])
plot(one[:,0],one[:,4])
plot(one[:,0],one[:,5])

# %%
B = np.loadtxt('b.dat')

# %%
plot(B[:,0],B[:,3])
plot(B[:,0],B[:,4])
plot(B[:,0],B[:,5])

# %%
plot(A[:,0],A[:,5])
plot(A[:,0],A[:,6])
xlim([10,20])
# Out:
# (10, 20)

# %%
plot(A[:,0],A[:,7])

# %%
'''
0 t2f
1 af
2 bf
3 abf
'''
# Out:
# '\n0 t2f\n1 af\n2 bf\n3 abf\n'

# %%
one = np.loadtxt('one_cell.dat')

# %%
plot(one[:,0],one[:,3])
plot(one[:,0],one[:,4])
plot(one[:,0],one[:,5])
plot(500.0/3.0*np.ones(2),np.linspace(0,35,2))

# %%
many = np.loadtxt('many_cells.dat')

# %%
one[-1,:]
# Out:
# array([ 226.008926,    0.      ,    0.      ,    2.      ,    0.      ,
#           0.      ,    1.      ])

# %%
plt.scatter(many[:,4],many[:,0])

# %%
plt.scatter(many[:,1],many[:,0])

# %%
one = np.loadtxt("one_one_cell.dat")

# %%
plot(one[:,0],one[:,3])
plot(one[:,0],one[:,4])
#plot(one[:,0],one[:,5])
